# %% [markdown]
# ## Problem 1
#
# The code below should repeat the user’s message the number of times that the user wants. The code has 5 lines that are not in the correct order. Rearrange the code by entering the number that corresponds to each line of code (whatever you think should be the first line of code will have number 1 in front of it).
#
#
# # Corrected order:
# 1: message = input("Enter a message (blank to quit): ")
# 2: while message != "":
# 3:     n = int(input("How many times should it be repeated? "))
# 4:     for i in range(n):
# 5:         print(message)

# %% [markdown]
# | Line Number | Code |
# |-------------|------|
# |  3          | `n = int(input("How many times should it be repeated? "))` |
# |  4          | `for i in range(n):` |
# |  5          | `print(message)` |
# |  2          | `while message != "":` |
# |  1          | `message = input("Enter a message (blank to quit): ")` |

# %%
message = input("Enter a message (blank to quit): ")
while message != "":
    n = int(input("How many times should it be repeated? "))
    for i in range(n):
        print(message)
    message = input("Enter a message (blank to quit): ")
# Out:
# 3
# 3

# %% [markdown]
# This code will determine whether or not a string entered by the user is a palindrome or not is not. The code has 11 lines that are not in the correct order. Rearrange the code by entering the number that corresponds to each line of code (whatever you think should be the first line of code will have number 1 in front of it — seen in the table).
#
# # Corrected order:
# 1: line = input("Enter a string: ")
# 2: is_palindrome = True
# 3: i = 0
# 4: while i < len(line) // 2:
# 5:     if line[i] != line[len(line) - i - 1]:
# 6:         is_palindrome = False
# 7:         break
# 8:     i += 1
# 9: if is_palindrome:
# 10:     print(line, "is a palindrome")
# 11: else:
# 12:     print(line, "is not a palindrome")

# %% [markdown]
# ## Problem 3
#
# When the following code runs, it asks for the name and then the age. If the age is under or equal to 10, the message is Hi followed by the name. The code has 13 lines that are not in the correct order. Rearrange the code by entering the number that corresponds to each line of code (whatever you think should be the first line of code will have number 1 in front of it – seen in the table).
#
# | Line Number | Code |
# |-------------|------|
# |             | `def main():` |
# |             | `if age <= 10:` |
# |             | `return data_tuple` |
# |             | `print("Hi", username)` |
# |             | `username = input("Enter your user name: ")` |
# | 1           | `message(username, age)` |
# |             | `def get_data():` |
# |             | `def message(username, age):` |
# |             | `age = int(input("Enter your age: "))` |
# |             | `data_tuple = (username, age)` |
# |             | `username, age = get_data()` |
# |             | `print("Hello", username)` |
# |             | `else:` |

# %%
def get_data():
    username = input("Enter your user name: ")
    age = int(input("Enter your age: "))
    data_tuple = (username, age)
    return data_tuple


def message(username, age):
    if age <= 10:
        print("Hello", username)
    else:
        print("Hi", username)


def main():
    username, age = get_data()
    message(username, age)

# %% [markdown]
# | Line Number | Code |
# |-------------|------|
# |  11          | `def main():` |
# |  7          | `if age <= 10:` |
# |  5          | `return data_tuple` |
# |  10          | `print("Hi", username)` |
# |  2          | `username = input("Enter your user name: ")` |
# |  13          | `message(username, age)` |
# |  1          | `def get_data():` |
# |  6          | `def message(username, age):` |
# |  3          | `age = int(input("Enter your age: "))` |
# |  4          | `data_tuple = (username, age)` |
# |  12          | `username, age = get_data()` |
# |  8          | `print("Hello", username)` |
# |  9          | `else:` |

# %% [markdown]
# ## Problem 4: Debugging code
#
# The code below should display a menu, add or subtract two numbers and display the corresponding message. However, the code is not working. Identify the issues that affect this code.
#
# Identify the lines with errors. How many errors did you find and what are the errors?
#
# ### Code with Errors
#
# ```python
# import random  # noqa: F811
#
# def addition():
#     num1 = random.randint(5,20)
#     num2 = random.randint(5,20)
#     print(num1, "+", num2, "= ")
#     user_answer = int(input("Your answer: "))
#     actual_answer = num1 + num2
#     answers = (user_answer, actual_answer)
#     return answer
#
# def subtraction():
#     num3 = random.randint(25,50)
#     num4 = random.randint(1,25)
#     print(num3, "-", num4, "= ")
#     user_answer = int(input("Your answer: "))
#     actual_answer == num3 - num4
#     answers = (user_answer, actual_answer):
#     return answers
#
# def check_answer(user_answer,actual_answer):
#     if user_answer == actual_answer:
#         print("Correct")
#     else:
#         print("Incorrect, the answer is ", actual_answer)
#
# def main():
#     print("(1) Addition")
#     print("(2) Subtraction")
#     selection = int(input("Enter 1 or 2: "))
#     if selection = 1:
#         user_answers, actual_answer = addition()
#         check_answer(user_answer, actual_answer)
#     elif selection == 2:
#         user_answer, actual_answer = subtraction()
#         check_answer(user_answer actual_answer)
#     else:
#         print("Incorrect selection")
# main()
# ```

# %%
import random  # noqa: F811


def addition():
    num1 = random.randint(5, 20)
    num2 = random.randint(5, 20)
    print(num1, "+", num2, "= ")
    user_answer = int(input("Your answer: "))
    actual_answer = num1 + num2
    answers = (user_answer, actual_answer)
    return answers  # add a s


def subtraction():
    num3 = random.randint(25, 50)
    num4 = random.randint(1, 25)
    print(num3, "-", num4, "= ")
    user_answer = int(input("Your answer: "))
    actual_answer = num3 - num4  # delete =
    answers = (user_answer, actual_answer)  # remove :
    return answers


def check_answer(user_answer, actual_answer):
    if user_answer == actual_answer:
        print("Correct")
    else:
        print("Incorrect, the answer is ", actual_answer)


def main():  # noqa: F811
    print("(1) Addition")
    print("(2) Subtraction")
    selection = int(input("Enter 1 or 2: "))
    if selection == 1:  # add a =
        user_answer, actual_answer = addition()
        check_answer(user_answer, actual_answer)
    elif selection == 2:
        user_answer, actual_answer = subtraction()
        check_answer(user_answer, actual_answer)  # add a ,
    else:
        print("Incorrect selection")


main()
# Out:
# (1) Addition
# (2) Subtraction
# 11 + 14 =
# Correct

# %% [markdown]
# ## Problem 5:
# This programme will ask the user to pick a low and high number, and then generate a random number between those two values and store it in a variable called “comp_num”. It will give the instruction “I am thinking of a number ...” and then ask the user to guess the number they are thinking of.
#
# Incomplete function: The third function should check to see if the comp_num is the same as the user’s guess. If it is, it should display the message “Correct, you win”, otherwise it should keep looking, telling the user if they are too low or too high and asking them to guess again (using a variable called try_again) until they guess correctly.
#
# Task: Using a pen and paper, complete the function (with correct indentation).
# ```python
# import random  # noqa: F811
#
# def pick_number():
#     low = int(input("Enter the bottom of the range: "))
#     high = int(input("Enter the top of the range: "))
#     comp_num = random.randint(low, high)
#     return comp_num
#
# def first_guess():
#     print("I am thinking of a number ... ")
#     guess = int(input("What am I thinking of: "))
#     return guess
#
# def check_answer(comp_num, guess):
#
# def main():
#     comp_num = pick_number()
#     guess = first_guess()
#     check_answer(comp_num, guess)
#
# main()
# ```

# %%
import random  # noqa: F811


def pick_number():
    low = int(input("Enter the bottom of the range: "))
    high = int(input("Enter the top of the range: "))
    comp_num = random.randint(low, high)
    return comp_num


def first_guess():
    print("I am thinking of a number ... ")
    guess = int(input("What am I thinking of: "))
    return guess


def check_answer(comp_num, guess):  # noqa: F811
    if comp_num == guess:
        print("Your answer is right!")
    else:
        print("Your answer is wrong!")


def main():  # noqa: F811
    comp_num = pick_number()
    guess = first_guess()
    check_answer(comp_num, guess)


main()
# Out:
# I am thinking of a number ...
